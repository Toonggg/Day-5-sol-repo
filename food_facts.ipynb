# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Step 2. Download the dataset to your computer and unzip it.

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %%
import pandas as pd

# %%
food = pd.read_csv('en.openfoodfacts.org.products.tsv',  sep = '\t' , error_bad_lines = False, warn_bad_lines = False)
#dir(food)
# Out:
# /opt/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
num_rows = food.shape[0] 
num_cols = food.shape[1] 

food_5 = food[0:20] 
food_5
# Out:
#      code                                                url  \
# 0    3087  http://world-en.openfoodfacts.org/product/0000...
# 1    4530  http://world-en.openfoodfacts.org/product/0000...
# 2    4559  http://world-en.openfoodfacts.org/product/0000...
# 3   16087  http://world-en.openfoodfacts.org/product/0000...
# 4   16094  http://world-en.openfoodfacts.org/product/0000...
# 5   16100  http://world-en.openfoodfacts.org/product/0000...
# 6   16117  http://world-en.openfoodfacts.org/product/0000...
# 7   16124  http://world-en.openfoodfacts.org/product/0000...
# 8   16193  http://world-en.openfoodfacts.org/product/0000...
# 9   16513  http://world-en.openfoodfacts.org/product/0000...
# 10  16612  http://world-en.openfoodfacts.org/product/0000...
# 11  16650  http://world-en.openfoodfacts.org/product/0000...
# 12  16872  http://world-en.openfoodfacts.org/product/0000...
# 13  16933  http://world-en.openfoodfacts.org/product/0000...
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
num_observations = num_rows
print("There are %i observations." %(num_observations))
# Out:
# There are 356027 observations.

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
print("There are %i columns." %(num_cols))
# Out:
# There are 163 columns.

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
for col in food.columns:
    print("Column name:", col)
# Out:
# Column name: code
# Column name: url
# Column name: creator
# Column name: created_t
# Column name: created_datetime
# Column name: last_modified_t
# Column name: last_modified_datetime
# Column name: product_name
# Column name: generic_name
# Column name: quantity
# Column name: packaging
# Column name: packaging_tags
# Column name: brands
# Column name: brands_tags
# Column name: categories
# Column name: categories_tags
# Column name: categories_en
# Column name: origins
# Column name: origins_tags
# Column name: manufacturing_places
# Column name: manufacturing_places_tags
# Column name: labels
# Column name: labels_tags
# Column name: labels_en
# Column name: emb_codes
# Column name: emb_codes_tags
# Column name: first_packaging_code_geo
# Column name: cities
# Column name: cities_tags
# Column name: purchase_places
# Column name: stores
# Column name: countries
# Column name: countries_tags
# Column name: countries_en
# Column name: ingredients_text
# Column name: allergens
# ...

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %%
nc = 105 - 1
print("Name of 105th column:", food.columns[nc])
# Out:
# Name of 105th column: -glucose_100g

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %%
food_105 = food[food.columns[nc]].dtypes
print("Data type of 105th column:", food_105)
# Out:
# Data type of 105th column: float64

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
print("Food is indexed as:", food.index)
# Out:
# Food is indexed as: RangeIndex(start=0, stop=356027, step=1)

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?

# %%
obs_19 = 19 - 1
prods = food['product_name']
print("Product name of the 19th observation:", prods[obs_19])
# Out:
# Product name of the 19th observation: Lotus Organic Brown Jasmine Rice
